# %%
import pandas as pd
import numpy as np
import time
import json
from datetime import datetime
import pickle

import torch

# %%
NEW_FOOTBALL_ID = -1
NUM_CLASSES = 23
NUM_AGENTS = 23

# %%
pd.options.display.max_columns = None

# %%
import sys

sys.path.append('../')

# %%
from utils import augment_ngs_frame

# %%
def create_ngs_df():
    ngs_df = pd.read_csv("../data/tracking_week_1.csv")
    print(f"dataframe shape = {ngs_df.shape}")
    for i in range(2,10):
        ngs_df = pd.concat([ngs_df,pd.read_csv(f"../data/tracking_week_{i}.csv") ])
    return ngs_df

# %%
''' 
Out of bounds plays don't need to have a tackle event: 2022110700_3429

'''
def filter_play_edges(ngs_play):
    events = set(ngs_play.event.unique())   # set of all events in 
    tocheck = ['penalty_flag'] # items to check
    events_in_play = [i for i in tocheck if i in events]
    if len(events_in_play) != 0:
        return pd.DataFrame()
    
    # filter edges
    tocheck = ['out_of_bounds', 'touchdown', 'fumble', 'safety', 'pass_outcome_touchdown', 'tackle'] # items to check
    end_events_in_play = [i for i in tocheck if i in events]
    print(f"end events in play = {end_events_in_play}")
    if len(end_events_in_play) != 0:
        end_frame_id = ngs_play.query("event in @end_events_in_play").frameId.unique().values[0]
        ngs_play = ngs_play.loc[ngs_play.frameId <= end_frame_id]
    
    print(f"final row = {ngs_play.iloc[-1].event}")
    return ngs_play

# %%
''' 
Function to return pandas series of given play 
    also adds 'line_of_scrimmage' calculation
'''
def get_play(play_df : pd.DataFrame, game_id : np.int64, play_id : np.int64) -> pd.Series :
    play_info = play_df.loc[(play_df.gameId == game_id) & (play_df.playId == play_id)].iloc[0]
    # line of scrimmage
    YardsFromOwnGoal = np.where(play_info.yardlineSide == play_info.possessionTeam, play_info.yardlineNumber, 50 + (50-play_info.yardlineNumber))
    YardsFromOwnGoal = np.where(play_info.yardlineNumber == 50, 50, YardsFromOwnGoal)
    play_info['line_of_scrimmage'] = YardsFromOwnGoal.item()
    return play_info

# get tackler id
def get_tackler_id(tackles : pd.DataFrame, game_id : np.int64, play_id : np.int64, NEW_FOOTBALL_ID=-1):
    # get tackler info
    play_tackle_info = tackles.loc[(tackles.gameId == game_id) & (tackles.playId == play_id)]
    if play_tackle_info.tackle.sum() == 0:  
        if play_tackle_info.assist.sum() == 0: # no tackles on play
            tackler_id = NEW_FOOTBALL_ID        # set to football id, so future calculations easier
        else:                                   # there were assists, so remove
            return None
    else:
        tackler_id = play_tackle_info.loc[play_tackle_info.tackle == 1,'nflId'].item()
    return tackler_id

# %%
games = pd.read_csv("../data/games.csv")
players = pd.read_csv("../data/players.csv")
plays = pd.read_csv("../data/plays.csv")
tackles = pd.read_csv("../data/tackles.csv")

# %%
players['height_inches'] = players.height.apply(lambda x: int(x.split("-")[0])*12 + int(x.split("-")[1]))

# %%
''' 
return numpay array (9,)
['line_of_scrimmage', 'yards_to_go', 'quarter', 'down', 'seconds_left', 'def_win_prob', 'def_win_prob', 'week', 'is_thursday']
'''
def calc_game_features(game_info : pd.Series, play_info : pd.Series) -> list:

    game_datetime = datetime.strptime(game_info.gameDate + " " + game_info.gameTimeEastern, '%m/%d/%Y %H:%M:%S')
    is_thursday = int(game_datetime.weekday() == 3)

    min, sec = play_info.gameClock.split(":")
    seconds_left = int(min)*60 + int(sec)

    def_are_home = int((game_info.homeTeamAbbr == play_info.defensiveTeam)) #bool

    if def_are_home:
        def_win_prob = play_info.preSnapHomeTeamWinProbability
    else:
        def_win_prob = play_info.preSnapVisitorTeamWinProbability

    game_features = np.array([play_info.line_of_scrimmage, play_info.yardsToGo, play_info.quarter, play_info.down, seconds_left, def_are_home, def_win_prob, game_info.week, is_thursday])

    return game_features

# %%
players.position.unique()
# Out:
# array(['QB', 'T', 'TE', 'WR', 'DE', 'NT', 'SS', 'FS', 'G', 'OLB', 'DT',
#        'CB', 'RB', 'C', 'ILB', 'MLB', 'FB', 'LS', 'DB'], dtype=object)

# %%
ngs_df = create_ngs_df()
all_games = ngs_df.gameId.unique()
# Out:
# dataframe shape = (1407439, 17)

# %%
ngs_df.loc[ngs_df.club == 'football', 'nflId'] = NEW_FOOTBALL_ID

# %%
''' 
Create a dataset of sequences of length 164, IDed by (game_id)_(play_id)
'''

MAX_FRAME_ID = 164
SAVE=False

base_dir = f"seq_clipped_sorted_data"

game_play_id_list = []  # list of IDs
seq_length_list = []

feature_list = []
target_list = []
id_list = []
context_list = []

features_to_keep = ['attacking_team','football','ball_carrier','x_adj','y_adj','dir_adj','dir_o', 's', 'a', 'height_inches', 'weight']
game_features = ['line_of_scrimmage', 'yards_to_go', 'quarter', 'down', 'seconds_left', 'def_win_prob', 'def_win_prob', 'week', 'is_thursday']

# %%
num_plays_kept = 0
penalty_plays = 0
assist_plays = 0
plays_removed_in_clipped = 0
start_time = time.time()
print(f"Starting collection...")

for game_index, game_id in enumerate(all_games):
    all_play_ids = plays.query("gameId == @game_id").playId.values
    for play_id in all_play_ids:
        try:
            current_id = f"{str(game_id)}_{str(play_id)}"
            
            play_info = get_play(plays, game_id, play_id)                   # store play info in series
            if not np.isnan(play_info.penaltyYards):
                penalty_plays += 1
                continue
            tackler_id = get_tackler_id(tackles, game_id, play_id)          # store tackler id
            if tackler_id == None:
                assist_plays += 1
                continue

            ngs_full_play = ngs_df.loc[(ngs_df.gameId == game_id) & (ngs_df.playId == play_id)].copy()
            ngs_full_play = filter_play_edges(ngs_full_play)
            if len(ngs_full_play) == 0:
                plays_removed_in_clipped += 1
                continue

            # add height and weight
            ngs_full_play = pd.merge(ngs_full_play, players.loc[:,['nflId', 'height_inches', 'weight']], how='left',on='nflId').fillna(0)

            frame_ids = ngs_full_play.frameId.unique()
            final_frame_in_play = int(frame_ids.max())
            seq_lengths = [final_frame_in_play]

            game_info = games.query("gameId==@game_id").iloc[0] # series
            game_features = calc_game_features(game_info, play_info)    # list len 9
            all_timesteps_game_features = np.tile(game_features.reshape(1,-1), (final_frame_in_play,1))
            # update time remaining
            all_timesteps_game_features[:,4] = all_timesteps_game_features[:,4] - np.arange(0,final_frame_in_play)*0.1

            # add info about play, which will be useful to visualize
            play_info_dict = {'tackler_id':tackler_id,
                                'final_frame_in_play':final_frame_in_play, 
                                'ball_carrier_id': play_info.ballCarrierId,
                                'playResult': play_info.playResult}
            #play_info_list = [tackler_id, final_frame_in_play, play_info.ballCarrierId, play_info.playResult]

            player_ids = []

            play_features_list = []
            play_targets_list = []
            for frame_id in range(1, final_frame_in_play+1):
                
                ngs_frame_df = ngs_full_play.loc[ngs_full_play.frameId == frame_id].copy()

                augment_ngs_frame(play_info.possessionTeam, play_info.ballCarrierId, ngs_frame_df)
                ngs_frame_df['tackle'] = (ngs_frame_df.nflId == tackler_id).astype(int)     # first entry represents 'no tackle'

                feature_matrix = ngs_frame_df[features_to_keep].to_numpy().flatten() # (23,9) -> (207,)
                target = ngs_frame_df.loc[:, 'tackle'].values  # (23,) array
                
                play_features_list.append(feature_matrix)
                play_targets_list.append(target)

                if len(player_ids) == 0:
                    player_ids = ngs_frame_df.nflId.unique() # numpy sorted array

            # # pad values at end
            for pad_id in range(0, MAX_FRAME_ID - final_frame_in_play):
                play_features_list.append(np.zeros(len(features_to_keep)*(NUM_AGENTS), dtype=np.int64))
                play_targets_list.append(np.zeros(NUM_CLASSES, dtype=np.int64))
            # pad values at end of game features
            full_context_vector = np.concatenate([all_timesteps_game_features, np.zeros((MAX_FRAME_ID - final_frame_in_play, all_timesteps_game_features.shape[1]))], axis=0)
            full_context_vector = torch.tensor(full_context_vector)
            
            if SAVE:
                torch.save(full_context_vector, f"../cleaned_data/{base_dir}/context_vector/{current_id}.pt")
                torch.save(torch.Tensor(play_features_list), f"../cleaned_data/{base_dir}/features/{current_id}.pt")
                torch.save(torch.Tensor(play_targets_list), f"../cleaned_data/{base_dir}/labels/{current_id}.pt")
                with open(f"../cleaned_data/{base_dir}/play_info_dict/{current_id}", 'wb') as file:
                   pickle.dump(play_info_dict, file)
                np.save(f"../cleaned_data/{base_dir}/player_ids/{current_id}.npy", player_ids)

            game_play_id_list.append(current_id)      # add ID to id list
            seq_length_list.append(seq_lengths)

            feature_list.append(play_features_list)
            target_list.append(play_targets_list)
            id_list.append(player_ids)
            context_list.append(full_context_vector)

            num_plays_kept += 1
        except Exception as e:
            print(f"skipping game {game_id}, play {play_id} bc exception {e}")
        
        if num_plays_kept % 1000 == 0:
            cur_time = time.time()
            print(f"Recorded {num_plays_kept} plays in {round((cur_time - start_time)/60, 3)} minutes")
        
    break

end_time = time.time()
print(f"Recorded {num_plays_kept} plays in {round((end_time - start_time)/60, 3)} minutes")
# Out:
# Starting collection...
# final row =            gameId playId nflId displayName frameId  \
# 44251  2022090800   2184  -1.0    football      44
#
#                              time jerseyNumber      club playDirection      x  \
# 44251  2022-09-08 22:01:31.700000          NaN  football          left  25.68
#
#                y     s     a  dis    o  dir event
# 44251  31.120001  1.59  3.31  0.2  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 44247  2022090800   2184  -1.0    football      40
#
#                              time jerseyNumber      club playDirection  \
# 44247  2022-09-08 22:01:31.299999          NaN  football          left
#
#                x      y     s     a   dis    o  dir   event
# 44247  25.629999  30.25  3.11  2.18  0.35  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 71460  2022090800   3304  -1.0    football      53
#
#                              time jerseyNumber      club playDirection  \
# 71460  2022-09-08 22:53:35.000000          NaN  football         right
#
#                x          y     s     a   dis    o  dir  \
# 71460  93.790001  38.880001  0.32  0.93  0.04  NaN  NaN
#
#                            event
# 71460  autoevent_passinterrupted
# final row event = autoevent_passinterrupted
# end events in play = ['fumble']
# final row = fumble
# final POST row event = fumble
# final POST row =            gameId playId nflId displayName frameId  \
# 71456  2022090800   3304  -1.0    football      49
#
#                              time jerseyNumber      club playDirection  \
# 71456  2022-09-08 22:53:34.599999          NaN  football         right
#
#                x      y     s     a   dis    o  dir   event
# 71456  93.599998  38.77  0.84  1.76  0.09  NaN  NaN  fumble
# final row =            gameId playId nflId displayName frameId  \
# 55705  2022090800   2648  -1.0    football      81
#
#                              time jerseyNumber      club playDirection  \
# 55705  2022-09-08 22:23:45.900000          NaN  football          left
#
#                x          y     s     a   dis    o  dir event
# 55705  65.879997  33.939999  0.76  1.83  0.17  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 55701  2022090800   2648  -1.0    football      77
#
#                              time jerseyNumber      club playDirection  \
# 55701  2022-09-08 22:23:45.500000          NaN  football          left
#
#                x      y     s     a   dis    o  dir   event
# 55701  65.449997  33.82  1.92  3.51  0.19  NaN  NaN  tackle
# final row =           gameId playId nflId displayName frameId                        time  \
# 6945  2022090800    236  -1.0    football      23  2022-09-08 20:29:06.200000
#
#      jerseyNumber      club playDirection     x          y    s     a   dis  \
# 6945          NaN  football          left  6.59  50.860001  7.8  4.31  0.79
#
#         o  dir event
# 6945  NaN  NaN   NaN
# final row event = nan
# end events in play = ['touchdown']
# final row = touchdown
# final POST row event = touchdown
# final POST row =           gameId playId nflId displayName frameId                        time  \
# 6941  2022090800    236  -1.0    football      19  2022-09-08 20:29:05.799999
#
#      jerseyNumber      club playDirection     x          y     s     a   dis  \
# 6941          NaN  football          left  9.83  50.080002  8.78  2.62  0.88
#
#         o  dir      event
# 6941  NaN  NaN  touchdown
# final row =            gameId playId nflId displayName frameId  \
# 46620  2022090800   2336  -1.0    football      29
#
#                              time jerseyNumber      club playDirection  \
# 46620  2022-09-08 22:08:34.799999          NaN  football         right
#
#                x          y     s     a   dis    o  dir event
# 46620  68.699997  34.040001  1.84  3.75  0.12  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 46616  2022090800   2336  -1.0    football      25
#
#                              time jerseyNumber      club playDirection      x  \
# 46616  2022-09-08 22:08:34.400000          NaN  football         right  67.75
#
#                y     s     a   dis    o  dir   event
# 46616  34.419998  3.55  2.56  0.36  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 61248  2022090800   2860  -1.0    football      22
#
#                              time jerseyNumber      club playDirection  \
# 61248  2022-09-08 22:34:51.799999          NaN  football          left
#
#                x          y     s    a   dis    o  dir event
# 61248  71.110001  36.610001  0.92  2.4  0.09  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 61244  2022090800   2860  -1.0    football      18
#
#                              time jerseyNumber      club playDirection  \
# 61244  2022-09-08 22:34:51.400000          NaN  football          left
#
#                x          y    s     a   dis    o  dir   event
# 61244  71.650002  36.490002  2.6  3.49  0.23  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 39214  2022090800   2072  -1.0    football      73
#
#                              time jerseyNumber      club playDirection  \
# 39214  2022-09-08 21:57:59.299999          NaN  football          left
#
#                x    y    s     a   dis    o  dir event
# 39214  58.080002  1.2  3.1  6.23  0.42  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 39210  2022090800   2072  -1.0    football      69
#
#                              time jerseyNumber      club playDirection  \
# 39210  2022-09-08 21:57:58.900000          NaN  football          left
#
#                x    y     s     a   dis    o  dir   event
# 39210  57.009998  2.6  3.18  1.68  0.48  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 40525  2022090800   2093  -1.0    football      57
#
#                              time jerseyNumber      club playDirection      x  \
# 40525  2022-09-08 21:58:44.299999          NaN  football          left  47.98
#
#            y     s     a   dis    o  dir event
# 40525  15.46  2.14  0.96  0.21  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 40521  2022090800   2093  -1.0    football      53
#
#                              time jerseyNumber      club playDirection  \
# 40521  2022-09-08 21:58:43.900000          NaN  football          left
#
#                x          y     s     a  dis    o  dir   event
# 40521  48.290001  16.209999  1.76  1.84  0.2  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 19112  2022090800    867  -1.0    football      28
#
#                              time jerseyNumber      club playDirection  \
# 19112  2022-09-08 20:55:09.599999          NaN  football         right
#
#                x     y     s     a   dis    o  dir event
# 19112  44.759998 -1.89  4.73  0.79  0.47  NaN  NaN   NaN
# final row event = nan
# end events in play = ['out_of_bounds']
# final row = out_of_bounds
# final POST row event = out_of_bounds
# final POST row =            gameId playId nflId displayName frameId  \
# 19108  2022090800    867  -1.0    football      24
#
#                              time jerseyNumber      club playDirection  \
# 19108  2022-09-08 20:55:09.200000          NaN  football         right
#
#                x     y     s     a  dis    o  dir          event
# 19108  43.779999 -0.34  3.94  1.26  0.4  NaN  NaN  out_of_bounds
# final row =            gameId playId nflId displayName frameId  \
# 15570  2022090800    617  -1.0    football      20
#
#                              time jerseyNumber      club playDirection  \
# 15570  2022-09-08 20:44:16.599999          NaN  football          left
#
#                x     y     s     a   dis    o  dir event
# 15570  62.080002 -1.12  2.28  1.97  0.23  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 15566  2022090800    617  -1.0    football      16
#
#                              time jerseyNumber      club playDirection      x  \
# 15566  2022-09-08 20:44:16.200000          NaN  football          left  61.75
#
#           y     s     a   dis    o  dir   event
# 15566 -0.17  2.74  3.39  0.28  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 35925  2022090800   1946  -1.0    football      53
#
#                              time jerseyNumber      club playDirection  \
# 35925  2022-09-08 21:52:34.099999          NaN  football         right
#
#                x      y     s     a   dis    o  dir event
# 35925  23.120001  11.43  0.52  1.11  0.06  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 35921  2022090800   1946  -1.0    football      49
#
#                              time jerseyNumber      club playDirection      x  \
# 35921  2022-09-08 21:52:33.700000          NaN  football         right  22.75
#
#            y     s     a  dis    o  dir   event
# 35921  11.28  1.15  2.46  0.2  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 31440  2022090800   1406  -1.0    football      47
#
#                              time jerseyNumber      club playDirection      x  \
# 31440  2022-09-08 21:18:23.900000          NaN  football          left  13.98
#
#                y     s     a   dis    o  dir event
# 31440  26.469999  0.83  2.19  0.13  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 31436  2022090800   1406  -1.0    football      43
#
#                              time jerseyNumber      club playDirection      x  \
# 31436  2022-09-08 21:18:23.500000          NaN  football          left  14.52
#
#                y     s     a   dis    o  dir   event
# 31436  26.129999  1.75  1.76  0.23  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 45585  2022090800   2232  -1.0    football      11
#
#                              time jerseyNumber      club playDirection     x  \
# 45585  2022-09-08 22:02:50.099999          NaN  football          left  7.95
#
#                y     s     a  dis    o  dir event
# 45585  30.290001  1.87  2.67  0.5  NaN  NaN   NaN
# final row event = nan
# end events in play = ['touchdown']
# final row = touchdown
# final POST row event = touchdown
# final POST row =            gameId playId nflId displayName frameId  \
# 45581  2022090800   2232  -1.0    football       7
#
#                              time jerseyNumber      club playDirection     x  \
# 45581  2022-09-08 22:02:49.700000          NaN  football          left  9.56
#
#                y     s     a   dis    o  dir      event
# 45581  30.950001  3.66  6.41  0.41  NaN  NaN  touchdown
# final row =            gameId playId nflId displayName frameId  \
# 21941  2022090800    980  -1.0    football      13
#
#                              time jerseyNumber      club playDirection  \
# 21941  2022-09-08 21:00:31.099999          NaN  football         right
#
#                x     y     s    a   dis    o  dir event
# 21941  46.619999  0.74  1.27  2.5  0.28  NaN  NaN   NaN
# final row event = nan
# end events in play = ['out_of_bounds']
# final row = out_of_bounds
# final POST row event = out_of_bounds
# final POST row =            gameId playId nflId displayName frameId  \
# 21937  2022090800    980  -1.0    football       9
#
#                              time jerseyNumber      club playDirection      x  \
# 21937  2022-09-08 21:00:30.700000          NaN  football         right  46.32
#
#           y     s     a   dis    o  dir          event
# 21937  1.03  1.07  0.55  0.11  NaN  NaN  out_of_bounds
# final row =            gameId playId nflId displayName frameId  \
# 30359  2022090800   1385  -1.0    football      76
#
#                              time jerseyNumber      club playDirection  \
# 30359  2022-09-08 21:17:54.400000          NaN  football          left
#
#                x      y     s     a   dis    o  dir event
# 30359  16.889999  17.08  0.44  1.76  0.04  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 30355  2022090800   1385  -1.0    football      72
#
#                              time jerseyNumber      club playDirection  \
# 30355  2022-09-08 21:17:54.000000          NaN  football          left
#
#                x      y     s     a   dis    o  dir   event
# 30355  17.219999  17.08  1.34  1.92  0.15  NaN  NaN  tackle
# final row =           gameId playId nflId displayName frameId                        time  \
# 1195  2022090800     80  -1.0    football      30  2022-09-08 20:24:38.599999
#
#      jerseyNumber      club playDirection          x     y     s     a   dis  \
# 1195          NaN  football          left  72.389999  44.0  3.14  5.77  0.33
#
#         o  dir event
# 1195  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =           gameId playId nflId displayName frameId                        time  \
# 1191  2022090800     80  -1.0    football      26  2022-09-08 20:24:38.200000
#
#      jerseyNumber      club playDirection          x          y    s     a  \
# 1191          NaN  football          left  73.129997  42.470001  5.3  4.13
#
#        dis    o  dir   event
# 1191  0.54  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 49656  2022090800   2485  -1.0    football      52
#
#                              time jerseyNumber      club playDirection  \
# 49656  2022-09-08 22:15:14.000000          NaN  football          left
#
#                x     y     s     a   dis    o  dir event
# 49656  88.220001  4.08  3.34  4.48  0.38  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 49652  2022090800   2485  -1.0    football      48
#
#                              time jerseyNumber      club playDirection  \
# 49652  2022-09-08 22:15:13.599999          NaN  football          left
#
#                x     y     s     a   dis    o  dir   event
# 49652  89.010002  5.57  5.49  5.08  0.58  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 21642  2022090800    933  -1.0    football      69
#
#                              time jerseyNumber      club playDirection  \
# 21642  2022-09-08 20:57:01.200000          NaN  football          left
#
#                x          y    s     a   dis    o  dir event
# 21642  54.209999  27.280001  6.3  3.84  0.76  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 21638  2022090800    933  -1.0    football      65
#
#                              time jerseyNumber      club playDirection  \
# 21638  2022-09-08 20:57:00.799999          NaN  football          left
#
#                x      y     s      a   dis    o  dir   event
# 21638  51.540001  26.84  5.22  11.54  0.44  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 41583  2022090800   2137  -1.0    football      46
#
#                              time jerseyNumber      club playDirection      x  \
# 41583  2022-09-08 22:00:05.400000          NaN  football          left  44.09
#
#           y     s     a   dis    o  dir event
# 41583 -1.47  5.42  2.34  0.55  NaN  NaN   NaN
# final row event = nan
# end events in play = ['out_of_bounds']
# final row = out_of_bounds
# final POST row event = out_of_bounds
# final POST row =            gameId playId nflId displayName frameId  \
# 41579  2022090800   2137  -1.0    football      42
#
#                              time jerseyNumber      club playDirection  \
# 41579  2022-09-08 22:00:05.000000          NaN  football          left
#
#                x     y     s     a  dis    o  dir          event
# 41579  45.669998  0.28  6.08  4.06  0.6  NaN  NaN  out_of_bounds
# final row =            gameId playId nflId displayName frameId  \
# 48460  2022090800   2464  -1.0    football      40
#
#                              time jerseyNumber      club playDirection  \
# 48460  2022-09-08 22:14:33.099999          NaN  football          left
#
#                x      y     s    a   dis    o  dir event
# 48460  96.860001  11.73  1.41  3.1  0.15  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 48456  2022090800   2464  -1.0    football      36
#
#                              time jerseyNumber      club playDirection      x  \
# 48456  2022-09-08 22:14:32.700000          NaN  football          left  97.07
#
#            y     s     a   dis    o  dir   event
# 48456  12.48  3.43  3.07  0.36  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 45332  2022090800   2208  -1.0    football      47
#
#                              time jerseyNumber      club playDirection  \
# 45332  2022-09-08 22:02:11.500000          NaN  football          left
#
#                x     y     s     a   dis    o  dir event
# 45332  17.629999  0.67  0.87  1.81  0.09  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 45328  2022090800   2208  -1.0    football      43
#
#                              time jerseyNumber      club playDirection  \
# 45328  2022-09-08 22:02:11.099999          NaN  football          left
#
#                x     y     s    a   dis    o  dir   event
# 45328  18.049999  0.75  1.84  1.8  0.33  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 74220  2022090800   3383  -1.0    football      34
#
#                              time jerseyNumber      club playDirection  \
# 74220  2022-09-08 22:57:14.700000          NaN  football          left
#
#                x          y     s     a   dis    o  dir event
# 74220  76.190002  39.650002  0.71  2.21  0.09  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 74216  2022090800   3383  -1.0    football      30
#
#                              time jerseyNumber      club playDirection  \
# 74216  2022-09-08 22:57:14.299999          NaN  football          left
#
#                x          y     s     a   dis    o  dir   event
# 74216  76.589996  39.880001  1.96  3.99  0.26  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 33096  2022090800   1736  -1.0    football      31
#
#                              time jerseyNumber      club playDirection  \
# 33096  2022-09-08 21:32:43.700000          NaN  football          left
#
#                x          y     s     a   dis    o  dir event
# 33096  41.240002  28.860001  2.43  4.79  0.24  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 33092  2022090800   1736  -1.0    football      27
#
#                              time jerseyNumber      club playDirection  \
# 33092  2022-09-08 21:32:43.299999          NaN  football          left
#
#                x          y     s     a   dis    o  dir   event
# 33092  42.099998  29.690001  4.34  1.57  0.48  NaN  NaN  tackle
# final row =           gameId playId nflId displayName frameId                        time  \
# 9337  2022090800    364  -1.0    football      12  2022-09-08 20:35:18.500000
#
#      jerseyNumber      club playDirection          x     y    s     a   dis  \
# 9337          NaN  football         right  53.959999 -2.21  5.3  2.74  0.54
#
#         o  dir event
# 9337  NaN  NaN   NaN
# final row event = nan
# end events in play = ['out_of_bounds']
# final row = out_of_bounds
# final POST row event = out_of_bounds
# final POST row =           gameId playId nflId displayName frameId                        time  \
# 9333  2022090800    364  -1.0    football       8  2022-09-08 20:35:18.099999
#
#      jerseyNumber      club playDirection      x     y     s     a   dis    o  \
# 9333          NaN  football         right  52.52 -0.42  6.29  0.73  0.63  NaN
#
#       dir          event
# 9333  NaN  out_of_bounds
# final row =            gameId playId nflId displayName frameId  \
# 64491  2022090800   3092  -1.0    football      33
#
#                              time jerseyNumber      club playDirection  \
# 64491  2022-09-08 22:46:55.200000          NaN  football          left
#
#                x     y     s     a   dis    o  dir event
# 64491  85.830002 -2.54  5.13  3.03  0.53  NaN  NaN   NaN
# final row event = nan
# end events in play = ['out_of_bounds']
# final row = out_of_bounds
# final POST row event = out_of_bounds
# final POST row =            gameId playId nflId displayName frameId  \
# 64487  2022090800   3092  -1.0    football      29
#
#                              time jerseyNumber      club playDirection      x  \
# 64487  2022-09-08 22:46:54.799999          NaN  football          left  86.32
#
#           y     s    a   dis    o  dir          event
# 64487 -0.29  6.22  2.7  0.63  NaN  NaN  out_of_bounds
# final row =            gameId playId nflId displayName frameId  \
# 17295  2022090800    692  -1.0    football      37
#
#                              time jerseyNumber      club playDirection  \
# 17295  2022-09-08 20:46:05.400000          NaN  football          left
#
#                x          y     s     a   dis    o  dir event
# 17295  39.119999  38.799999  0.41  0.44  0.06  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 17291  2022090800    692  -1.0    football      33
#
#                              time jerseyNumber      club playDirection      x  \
# 17291  2022-09-08 20:46:05.000000          NaN  football          left  39.23
#
#                y     s     a   dis    o  dir   event
# 17291  38.709999  0.43  2.25  0.04  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 53451  2022090800   2572  -1.0    football      26
#
#                              time jerseyNumber      club playDirection  \
# 53451  2022-09-08 22:17:58.299999          NaN  football          left
#
#                x          y     s     a   dis    o  dir event
# 53451  72.139999  20.870001  1.24  0.57  0.13  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 53447  2022090800   2572  -1.0    football      22
#
#                              time jerseyNumber      club playDirection  \
# 53447  2022-09-08 22:17:57.900000          NaN  football          left
#
#                x          y     s    a   dis    o  dir   event
# 53447  72.650002  21.040001  1.35  1.9  0.14  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 58166  2022090800   2755  -1.0    football      28
#
#                              time jerseyNumber      club playDirection  \
# 58166  2022-09-08 22:29:07.500000          NaN  football         right
#
#                 x     y     s     a   dis    o  dir event
# 58166  110.629997  6.89  2.66  4.42  0.28  NaN  NaN   NaN
# final row event = nan
# end events in play = ['touchdown']
# final row = touchdown
# final POST row event = touchdown
# final POST row =            gameId playId nflId displayName frameId  \
# 58162  2022090800   2755  -1.0    football      24
#
#                              time jerseyNumber      club playDirection  \
# 58162  2022-09-08 22:29:07.099999          NaN  football         right
#
#                 x     y     s     a   dis    o  dir      event
# 58162  110.559998  8.29  4.62  4.37  0.47  NaN  NaN  touchdown
# final row =            gameId playId nflId displayName frameId  \
# 63479  2022090800   2958  -1.0    football      57
#
#                              time jerseyNumber      club playDirection  \
# 63479  2022-09-08 22:40:09.299999          NaN  football         right
#
#                x          y     s     a   dis    o  dir event
# 63479  56.689999  21.370001  0.29  0.85  0.03  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 63475  2022090800   2958  -1.0    football      53
#
#                              time jerseyNumber      club playDirection  \
# 63475  2022-09-08 22:40:08.900000          NaN  football         right
#
#                x      y     s     a   dis    o  dir   event
# 63475  56.450001  21.42  0.82  1.99  0.09  NaN  NaN  tackle
# final row =            gameId playId nflId displayName frameId  \
# 67734  2022090800   3190  -1.0    football      21
#
#                              time jerseyNumber      club playDirection  \
# 67734  2022-09-08 22:50:18.900000          NaN  football          left
#
#                x          y     s     a   dis    o  dir event
# 67734  65.309998  52.380001  1.71  2.91  0.18  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =            gameId playId nflId displayName frameId  \
# 67730  2022090800   3190  -1.0    football      17
#
#                              time jerseyNumber      club playDirection     x  \
# 67730  2022-09-08 22:50:18.500000          NaN  football          left  65.5
#
#                y     s     a   dis    o  dir   event
# 67730  51.419998  3.26  3.77  0.34  NaN  NaN  tackle
# final row =           gameId playId nflId displayName frameId                        time  \
# 8164  2022090800    299  -1.0    football      53  2022-09-08 20:33:35.700000
#
#      jerseyNumber      club playDirection          x      y     s     a   dis  \
# 8164          NaN  football         right  32.279999  30.43  0.22  0.66  0.02
#
#         o  dir event
# 8164  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =           gameId playId nflId displayName frameId                        time  \
# 8160  2022090800    299  -1.0    football      49  2022-09-08 20:33:35.299999
#
#      jerseyNumber      club playDirection      x      y    s     a  dis    o  \
# 8160          NaN  football         right  32.18  30.33  0.7  1.59  0.1  NaN
#
#       dir   event
# 8160  NaN  tackle
# final row =          gameId playId nflId displayName frameId                        time  \
# 505  2022090800     56  -1.0    football      22  2022-09-08 20:24:07.299999
#
#     jerseyNumber      club playDirection          x      y     s     a   dis  \
# 505          NaN  football          left  78.290001  36.07  0.02  0.07  0.32
#
#        o  dir event
# 505  NaN  NaN   NaN
# final row event = nan
# end events in play = ['tackle']
# final row = tackle
# final POST row event = tackle
# final POST row =          gameId playId nflId displayName frameId                        time  \
# 501  2022090800     56  -1.0    football      18  2022-09-08 20:24:06.900000
#
#     jerseyNumber      club playDirection          x          y     s     a  \
# 501          NaN  football          left  78.160004  36.650002  0.07  0.27
#
#       dis    o  dir   event
# 501  0.01  NaN  NaN  tackle
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/scottmaran/Code/Python/bdb_2024/create_cleaned_data/player_info_preprocess.ipynb Cell 16 line 2
#      <a href='vscode-notebook-cell:/Users/scottmaran/Code/Python/bdb_2024/create_cleaned_data/player_info_preprocess.ipynb#X21sZmlsZQ%3D%3D?line=19'>20</a>     assist_plays += 1
#      <a href='vscode-notebook-cell:/Users/scottmaran/Code/Python/bdb_2024/create_cleaned_data/player_info_preprocess.ipynb#X21sZmlsZQ%3D%3D?line=20'>21</a>     continue
# ---> <a href='vscode-notebook-cell:/Users/scottmaran/Code/Python/bdb_2024/create_cleaned_data/player_info_preprocess.ipynb#X21sZmlsZQ%3D%3D?line=22'>23</a> ngs_full_play = ngs_df.loc[(ngs_df.gameId == game_id) & (ngs_df.playId == play_id)].copy()
#      <a href='vscode-notebook-cell:/Users/scottmaran/Code/Python/bdb_2024/create_cleaned_data/player_info_preprocess.ipynb#X21sZmlsZQ%3D%3D?line=23'>24</a> print(f"final row = {pd.DataFrame(ngs_full_play.iloc[-1]).T}")
#      <a href='vscode-notebook-cell:/Users/scottmaran/Code/Python/bdb_2024/create_cleaned_data/player_info_preprocess.ipynb#X21sZmlsZQ%3D%3D?line=24'>25</a> print(f"final row event = {ngs_full_play.iloc[-1].event}")
#
# File ~/.pyenv/versions/3.8.18/envs/bdb_2024/lib/python3.8/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~/.pyenv/versions/3.8.18/envs/bdb_2024/lib/python3.8/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/.pyenv/versions/3.8.18/envs/bdb_2024/lib/python3.8/site-packages/pandas/core/series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6095 with np.errstate(all="ignore"):
# -> 6096     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6098 return self._construct_result(res_values, name=res_name)
#
# File ~/.pyenv/versions/3.8.18/envs/bdb_2024/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:296, in comparison_op(left, right, op)
#     293     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     295 else:
# --> 296     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#     298 return res_values
#
# File ~/.pyenv/versions/3.8.18/envs/bdb_2024/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     168     func = partial(expressions.evaluate, op)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#     173     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     174         # For object dtype, fallback to a masked operation (only operating
#     175         #  on the non-missing values)
#     176         # Don't do this for comparisons, as that will handle complex numbers
#     177         #  incorrectly, see GH#32047
#
# File ~/.pyenv/versions/3.8.18/envs/bdb_2024/lib/python3.8/site-packages/pandas/core/computation/expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     236 if op_str is not None:
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~/.pyenv/versions/3.8.18/envs/bdb_2024/lib/python3.8/site-packages/pandas/core/computation/expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      68 if _TEST_MODE:
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# KeyboardInterrupt:

# %%
seq_length_tensor = torch.Tensor(seq_length_list)
feature_tensor = torch.Tensor(feature_list)
target_tensor = torch.Tensor(target_list)
context_tensor = torch.stack(context_list)

id_list = np.array(id_list)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/scottmaran/Code/Python/bdb_2024/create_cleaned_data/player_info_preprocess.ipynb Cell 17 line 4
#       <a href='vscode-notebook-cell:/Users/scottmaran/Code/Python/bdb_2024/create_cleaned_data/player_info_preprocess.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> feature_tensor = torch.Tensor(feature_list)
#       <a href='vscode-notebook-cell:/Users/scottmaran/Code/Python/bdb_2024/create_cleaned_data/player_info_preprocess.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> target_tensor = torch.Tensor(target_list)
# ----> <a href='vscode-notebook-cell:/Users/scottmaran/Code/Python/bdb_2024/create_cleaned_data/player_info_preprocess.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> context_tensor = torch.stack(context_list)
#       <a href='vscode-notebook-cell:/Users/scottmaran/Code/Python/bdb_2024/create_cleaned_data/player_info_preprocess.ipynb#X22sZmlsZQ%3D%3D?line=5'>6</a> id_list = np.array(id_list)
#
# RuntimeError: stack expects a non-empty TensorList

# %%
print(f"Number of plays:")
print(f"Kept={num_plays_kept}")
print(f"w/ penalties={penalty_plays}")
print(f"w/ assists (removed)={assist_plays}")
print(f"w/ clipped (removed)={plays_removed_in_clipped}")
# Out:
# Number of plays:
# Kept=9928
# w/ penalties=615
# w/ assists (removed)=1934
# w/ clipped (removed)=0

# %%
with open(f"../cleaned_data/{base_dir}/game_play_id.json", 'w') as f:
    json.dump(game_play_id_list, f, indent=2) 

torch.save(seq_length_tensor, f"../cleaned_data/{base_dir}/seq_length_tensor.pt")
torch.save(feature_tensor, f"../cleaned_data/{base_dir}/all_features.pt")
torch.save(target_tensor, f"../cleaned_data/{base_dir}/all_targets.pt")
torch.save(context_tensor, f"../cleaned_data/{base_dir}/all_context.pt")
np.save(f"../cleaned_data/{base_dir}/all_id_info.npy", np.array(id_list))

# %%
''' Test area '''
pd.set_option('display.max_columns', None)

# %%
ngs_df.query("event == 'tackle'").drop_duplicates(subset=['gameId', 'playId', 'frameId'])
# Out:
#              gameId  playId    nflId     displayName  frameId  \
# 17       2022090800      56  35472.0  Rodger Saffold       18
# 531      2022090800      80  35472.0  Rodger Saffold       26
# 1240     2022090800     101  35472.0  Rodger Saffold       45
# 2351     2022090800     122  35472.0  Rodger Saffold       29
# 3133     2022090800     146  35472.0  Rodger Saffold       52
# ...             ...     ...      ...             ...      ...
# 1143660  2022110700    3658  37724.0    Chris Harris       55
# 1145034  2022110700    3686  38557.0   Kevin Zeitler       72
# 1146764  2022110700    3707  38557.0   Kevin Zeitler       54
# 1148082  2022110700    3740  38557.0   Kevin Zeitler       38
# 1149050  2022110700    3787  37110.0     Andy Dalton       40
#
#                                time  jerseyNumber club playDirection      x  \
# 17       2022-09-08 20:24:06.900000          76.0  BUF          left  88.23
# 531      2022-09-08 20:24:38.200000          76.0  BUF          left  81.32
# 1240     2022-09-08 20:25:12.599999          76.0  BUF          left  67.52
# 2351     2022-09-08 20:25:53.799999          76.0  BUF          left  61.27
# 3133     2022-09-08 20:26:34.500000          76.0  BUF          left  54.09
# ...                             ...           ...  ...           ...    ...
# 1143660  2022-11-07 22:59:53.200000          19.0   NO          left  47.31
# 1145034  2022-11-07 23:00:38.299999          70.0  BAL          left  59.60
# 1146764  2022-11-07 23:03:50.799999          70.0  BAL          left  59.08
# 1148082  2022-11-07 23:04:34.900000          70.0  BAL          left  57.66
# 1149050  2022-11-07 23:06:49.200000          14.0   NO         right  16.76
#
#              y     s     a   dis       o     dir   event
# 17       27.09  1.72  0.26  0.18  288.76  302.08  tackle
# 531      27.31  1.84  0.61  0.19  313.15  304.54  tackle
# 1240     35.38  1.56  0.93  0.16  263.27  302.92  tackle
# 2351     42.23  5.97  2.44  0.62  311.46  304.49  tackle
# 3133     26.31  1.79  1.54  0.18  162.09  177.59  tackle
# ...        ...   ...   ...   ...     ...     ...     ...
# 1143660  17.86  0.47  2.84  0.06   99.00  218.21  tackle
# 1145034  31.40  1.26  1.47  0.14  265.72  296.85  tackle
# 1146764  29.28  1.55  0.30  0.16  328.32  330.42  tackle
# 1148082  21.35  3.72  0.78  0.39  171.54  182.88  tackle
# 1149050  23.47  0.86  0.41  0.08   93.43  104.61  tackle
#
# [10044 rows x 17 columns]

# %%
play_df = ngs_df.loc[(ngs_df.gameId == 2022090800) & (ngs_df.playId == 2184) & (ngs_df.displayName == 'football')]

# %%
play_df.head()
# Out:
#            gameId  playId  nflId displayName  frameId  \
# 44208  2022090800    2184   -1.0    football        1
# 44209  2022090800    2184   -1.0    football        2
# 44210  2022090800    2184   -1.0    football        3
# 44211  2022090800    2184   -1.0    football        4
# 44212  2022090800    2184   -1.0    football        5
#
#                              time  jerseyNumber      club playDirection  \
# 44208  2022-09-08 22:01:27.400000           NaN  football          left
# 44209  2022-09-08 22:01:27.500000           NaN  football          left
# 44210  2022-09-08 22:01:27.599999           NaN  football          left
# 44211  2022-09-08 22:01:27.700000           NaN  football          left
# 44212  2022-09-08 22:01:27.799999           NaN  football          left
#
#                x      y          s     a   dis   o  dir         event
# 44208  28.020000  12.04  22.540001  5.34  2.28 NaN  NaN  pass_arrived
# 44209  27.190001  11.58   4.740000  0.57  0.96 NaN  NaN           NaN
# 44210  27.250000  12.05   4.640000  1.22  0.47 NaN  NaN           NaN
# 44211  27.320000  12.50   4.510000  1.42  0.46 NaN  NaN           NaN
# 44212  27.370001  12.94   4.360000  1.58  0.44 NaN  NaN           NaN

# %%
tackles.query("gameId == 2022090800 and playId == 2184")
# Out:
#          gameId  playId  nflId  tackle  assist  forcedFumble  pff_missedTackle
# 638  2022090800    2184  52492       1       0             0                 0

# %%
ngs_df.query("nflId == 52492").head()
# Out:
#           gameId  playId    nflId    displayName  frameId  \
# 5743  2022090800     191  52492.0  Terrell Lewis        1
# 5744  2022090800     191  52492.0  Terrell Lewis        2
# 5745  2022090800     191  52492.0  Terrell Lewis        3
# 5746  2022090800     191  52492.0  Terrell Lewis        4
# 5747  2022090800     191  52492.0  Terrell Lewis        5
#
#                             time  jerseyNumber club playDirection      x  \
# 5743  2022-09-08 20:27:42.099999          52.0   LA          left  44.29
# 5744  2022-09-08 20:27:42.200000          52.0   LA          left  44.29
# 5745  2022-09-08 20:27:42.299999          52.0   LA          left  44.29
# 5746  2022-09-08 20:27:42.400000          52.0   LA          left  44.29
# 5747  2022-09-08 20:27:42.500000          52.0   LA          left  44.30
#
#           y    s    a   dis       o     dir event
# 5743  30.61  0.0  0.0  0.00   99.47  304.02   NaN
# 5744  30.61  0.0  0.0  0.00  101.74  295.25   NaN
# 5745  30.61  0.0  0.0  0.01  101.74  285.35   NaN
# 5746  30.60  0.0  0.0  0.01  101.74  270.48   NaN
# 5747  30.60  0.0  0.0  0.01  101.04  265.74   NaN

# %%
plays.query("gameId == 2022090800 and playId == 2184")
# Out:
#          gameId  playId  ballCarrierId ballCarrierDisplayName  \
# 209  2022090800    2184          42489           Stefon Diggs
#
#                                        playDescription  quarter  down  \
# 209  (9:24) (Shotgun) J.Allen pass short left to S....        3     1
#
#      yardsToGo possessionTeam defensiveTeam yardlineSide  yardlineNumber  \
# 209         10            BUF            LA           LA              22
#
#     gameClock  preSnapHomeScore  preSnapVisitorScore passResult  passLength  \
# 209      9:24                10                   10          C         4.0
#
#      penaltyYards  prePenaltyPlayResult  playResult playNullifiedByPenalty  \
# 209           NaN                     7           7                      N
#
#      absoluteYardlineNumber offenseFormation  defendersInTheBox  \
# 209                      32          SHOTGUN                5.0
#
#      passProbability  preSnapHomeTeamWinProbability  \
# 209         0.796962                       0.324996
#
#      preSnapVisitorTeamWinProbability  homeTeamWinProbabilityAdded  \
# 209                          0.675004                    -0.013726
#
#      visitorTeamWinProbilityAdded  expectedPoints  expectedPointsAdded  \
# 209                      0.013726          4.7305             0.406682
#
#     foulName1 foulName2  foulNFLId1  foulNFLId2
# 209       NaN       NaN         NaN         NaN

# %%
play_df = ngs_df.loc[(ngs_df.gameId == game_id) & (ngs_df.playId == play_id)]

# %%
players.height.apply(lambda x: int(x.split("-")[0])*12 + int(x.split("-")[1]))
# Out:
# 0       76
# 1       76
# 2       74
# 3       78
# 4       76
#         ..
# 1678    78
# 1679    72
# 1680    74
# 1681    73
# 1682    74
# Name: height, Length: 1683, dtype: int64

# %%
play_df_with_info = pd.merge(play_df, players.loc[:,['nflId', 'height_inches', 'weight']], how='left',on='nflId')

# %%
play_df.fillna(0)
# Out:
#            gameId  playId    nflId     displayName  frameId  \
# 19113  2022090800     896  35472.0  Rodger Saffold        1
# 19114  2022090800     896  35472.0  Rodger Saffold        2
# 19115  2022090800     896  35472.0  Rodger Saffold        3
# 19116  2022090800     896  35472.0  Rodger Saffold        4
# 19117  2022090800     896  35472.0  Rodger Saffold        5
# ...           ...     ...      ...             ...      ...
# 20051  2022090800     896     -1.0        football       37
# 20052  2022090800     896     -1.0        football       38
# 20053  2022090800     896     -1.0        football       39
# 20054  2022090800     896     -1.0        football       40
# 20055  2022090800     896     -1.0        football       41
#
#                              time  jerseyNumber      club playDirection  \
# 19113  2022-09-08 20:55:39.900000          76.0       BUF         right
# 19114  2022-09-08 20:55:40.000000          76.0       BUF         right
# 19115  2022-09-08 20:55:40.099999          76.0       BUF         right
# 19116  2022-09-08 20:55:40.200000          76.0       BUF         right
# 19117  2022-09-08 20:55:40.299999          76.0       BUF         right
# ...                           ...           ...       ...           ...
# 20051  2022-09-08 20:55:43.500000           0.0  football         right
# 20052  2022-09-08 20:55:43.599999           0.0  football         right
# 20053  2022-09-08 20:55:43.700000           0.0  football         right
# 20054  2022-09-08 20:55:43.799999           0.0  football         right
# 20055  2022-09-08 20:55:43.900000           0.0  football         right
#
#                x      y     s     a   dis       o     dir   event
# 19113  42.700000  25.54  0.01  0.01  0.00  115.69   22.90       0
# 19114  42.700000  25.54  0.01  0.01  0.00  116.60   29.20       0
# 19115  42.700000  25.54  0.01  0.01  0.01  117.76   41.92       0
# 19116  42.710000  25.53  0.00  0.01  0.01  118.54   61.56       0
# 19117  42.710000  25.52  0.01  0.14  0.01  118.54  130.83       0
# ...          ...    ...   ...   ...   ...     ...     ...     ...
# 20051  45.889999  12.99  4.73  5.46  0.49    0.00    0.00  fumble
# 20052  46.110001  12.59  4.29  5.39  0.45    0.00    0.00       0
# 20053  46.279999  12.20  4.08  5.00  0.43    0.00    0.00       0
# 20054  46.400002  11.80  4.06  4.75  0.41    0.00    0.00       0
# 20055  46.459999  11.37  4.41  4.75  0.44    0.00    0.00       0
#
# [943 rows x 17 columns]

# %%
play_df_with_info.nflId.unique()
# Out:
# array([ 3.5472e+04,  3.8577e+04,  4.1239e+04,  4.2392e+04,  4.2489e+04,
#         4.2816e+04,  4.3294e+04,  4.3298e+04,  4.4875e+04,  4.6076e+04,
#         4.7844e+04,  4.7857e+04,  4.7862e+04,  4.7879e+04,  4.7917e+04,
#         4.7939e+04,  4.8026e+04,  4.8512e+04,  5.2536e+04,  5.3522e+04,
#         5.3532e+04,  5.4528e+04, -1.0000e+00])

# %%
ngs_df.event.unique()
# Out:
# array([nan, 'pass_arrived', 'pass_outcome_caught', 'tackle', 'run',
#        'first_contact', 'ball_snap', 'handoff', 'touchdown',
#        'out_of_bounds', 'man_in_motion', 'fumble', 'play_action',
#        'pass_forward', 'lateral', 'autoevent_passforward',
#        'autoevent_passinterrupted', 'line_set', 'qb_slide', 'shift',
#        'run_pass_option', 'qb_sack', 'pass_shovel', 'autoevent_ballsnap',
#        'snap_direct', 'fumble_defense_recovered',
#        'fumble_offense_recovered', 'penalty_flag', 'safety',
#        'pass_outcome_touchdown', 'penalty_accepted'], dtype=object)

# %%
ngs_df.event.value_counts()
# Out:
# event
# first_contact                242262
# tackle                       230924
# ball_snap                    145408
# handoff                      135381
# pass_outcome_caught          130087
# pass_arrived                 113825
# out_of_bounds                 41629
# run                           21804
# man_in_motion                  9683
# touchdown                      9523
# play_action                    6463
# shift                          3358
# qb_slide                       3158
# fumble                         2415
# pass_forward                   1899
# snap_direct                    1150
# lateral                         618
# line_set                        552
# pass_shovel                     414
# autoevent_passforward           360
# autoevent_passinterrupted       324
# qb_sack                         230
# autoevent_ballsnap              162
# fumble_defense_recovered        115
# penalty_flag                     93
# fumble_offense_recovered         69
# safety                           69
# run_pass_option                  23
# pass_outcome_touchdown           22
# penalty_accepted                 22
# Name: count, dtype: int64

# %%
ngs_df.query("event == 'pass_outcome_touchdown'").iloc[0:30,:]
# Out:
#             gameId  playId    nflId         displayName  frameId  \
# 557138  2022092504    4168  38632.0        Kirk Cousins       10
# 557152  2022092504    4168  40488.0        Adam Thielen       10
# 557166  2022092504    4168  44834.0      Charles Harris       10
# 557180  2022092504    4168  44888.0       Alex Anzalone       10
# 557194  2022092504    4168  46099.0         Mike Hughes       10
# 557208  2022092504    4168  46131.0       Brian O'Neill       10
# 557222  2022092504    4168  46259.0      DeShon Elliott       10
# 557236  2022092504    4168  47801.0    Garrett Bradbury       10
# 557250  2022092504    4168  47833.0           Irv Smith       10
# 557264  2022092504    4168  47864.0         Will Harris       10
# 557278  2022092504    4168  47885.0  Alexander Mattison       10
# 557292  2022092504    4168  47929.0     Amani Oruwariye       10
# 557306  2022092504    4168  52411.0         Jeff Okudah       10
# 557320  2022092504    4168  52430.0    Justin Jefferson       10
# 557334  2022092504    4168  52466.0      Ezra Cleveland       10
# 557348  2022092504    4168  52475.0       Julian Okwara       10
# 557362  2022092504    4168  52584.0         K.J. Osborn       10
# 557376  2022092504    4168  52980.0         Juju Hughes       10
# 557390  2022092504    4168  53452.0  Christian Darrisaw       10
# 557404  2022092504    4168  53501.0        Alim McNeill       10
# 557418  2022092504    4168  54467.0    Aidan Hutchinson       10
# 557432  2022092504    4168  54524.0           Ed Ingram       10
#
#                               time  jerseyNumber club playDirection       x  \
# 557138  2022-09-25 16:09:46.500000           8.0  MIN         right   72.66
# 557152  2022-09-25 16:09:46.500000          19.0  MIN         right   94.69
# 557166  2022-09-25 16:09:46.500000          53.0  DET         right   72.80
# 557180  2022-09-25 16:09:46.500000          34.0  DET         right   84.71
# 557194  2022-09-25 16:09:46.500000          23.0  DET         right  107.97
# 557208  2022-09-25 16:09:46.500000          75.0  MIN         right   75.56
# 557222  2022-09-25 16:09:46.500000           5.0  DET         right  108.72
# 557236  2022-09-25 16:09:46.500000          56.0  MIN         right   80.61
# 557250  2022-09-25 16:09:46.500000          84.0  MIN         right   83.94
# 557264  2022-09-25 16:09:46.500000          25.0  DET         right   92.50
# 557278  2022-09-25 16:09:46.500000           2.0  MIN         right   84.11
# 557292  2022-09-25 16:09:46.500000          24.0  DET         right  100.65
# 557306  2022-09-25 16:09:46.500000           1.0  DET         right   99.24
# 557320  2022-09-25 16:09:46.500000          18.0  MIN         right  100.20
# 557334  2022-09-25 16:09:46.500000          72.0  MIN         right   80.85
# 557348  2022-09-25 16:09:46.500000          99.0  DET         right   74.87
# 557362  2022-09-25 16:09:46.500000          17.0  MIN         right  110.60
# 557376  2022-09-25 16:09:46.500000          33.0  DET         right   98.88
# 557390  2022-09-25 16:09:46.500000          71.0  MIN         right   70.96
# 557404  2022-09-25 16:09:46.500000          54.0  DET         right   74.54
# 557418  2022-09-25 16:09:46.500000          97.0  DET         right   82.48
# 557432  2022-09-25 16:09:46.500000          67.0  MIN         right   74.11
#
#             y     s     a   dis       o     dir                   event
# 557138  32.60  0.89  0.97  0.09  181.00  164.56  pass_outcome_touchdown
# 557152  10.82  3.47  1.92  0.35  138.43  159.52  pass_outcome_touchdown
# 557166  30.04  1.31  1.16  0.13  103.33  102.29  pass_outcome_touchdown
# 557180  44.04  4.87  2.53  0.50   16.07    6.26  pass_outcome_touchdown
# 557194  11.46  6.55  3.71  0.67  183.31  149.63  pass_outcome_touchdown
# 557208  25.05  2.70  0.08  0.29  126.19  129.96  pass_outcome_touchdown
# 557222  19.82  6.03  3.00  0.61  168.60  171.22  pass_outcome_touchdown
# 557236  23.93  3.03  0.63  0.31  114.25  135.13  pass_outcome_touchdown
# 557250   5.75  4.41  2.31  0.44  111.69  122.58  pass_outcome_touchdown
# 557264   6.40  6.08  1.73  0.61  114.48  112.29  pass_outcome_touchdown
# 557278  45.29  4.71  3.19  0.48   61.39   24.53  pass_outcome_touchdown
# 557292  11.77  1.82  2.55  0.19   94.44  123.22  pass_outcome_touchdown
# 557306  51.04  3.81  4.02  0.40   49.90  357.52  pass_outcome_touchdown
# 557320  51.68  1.48  3.16  0.16  147.87   20.47  pass_outcome_touchdown
# 557334  33.85  2.89  1.07  0.30  143.27  111.76  pass_outcome_touchdown
# 557348  22.86  2.81  0.87  0.28  130.42  132.22  pass_outcome_touchdown
# 557362   6.07  8.16  2.66  0.82  148.23  139.43  pass_outcome_touchdown
# 557376  17.86  2.96  1.93  0.30  150.43  155.46  pass_outcome_touchdown
# 557390  32.55  0.86  0.61  0.09  104.64  122.65  pass_outcome_touchdown
# 557404  30.33  0.53  0.59  0.06   79.80   38.33  pass_outcome_touchdown
# 557418  22.74  1.82  1.70  0.20   98.28  121.51  pass_outcome_touchdown
# 557432  28.62  1.01  0.33  0.10  101.73   93.72  pass_outcome_touchdown

# %%
game_id = 2022092504
play_id = 4168

# %%
play_info = get_play(plays, game_id, play_id)

# %%
tackler_id = get_tackler_id(tackles, game_id, play_id)

# %%
tackler_id
# Out:
# -1

# %%
pd.DataFrame(play_info).T
# Out:
#           gameId playId ballCarrierId ballCarrierDisplayName  \
# 5905  2022092504   4168         52584            K.J. Osborn
#
#                                         playDescription quarter down  \
# 5905  (:50) (Shotgun) K.Cousins pass deep right to K...       4    1
#
#      yardsToGo possessionTeam defensiveTeam yardlineSide yardlineNumber  \
# 5905        10            MIN           DET          DET             28
#
#      gameClock preSnapHomeScore preSnapVisitorScore passResult passLength  \
# 5905      0:50               21                  24          C       27.0
#
#      penaltyYards prePenaltyPlayResult playResult playNullifiedByPenalty  \
# 5905          NaN                   28         28                      N
#
#      absoluteYardlineNumber offenseFormation defendersInTheBox  \
# 5905                     82          SHOTGUN               5.0
#
#      passProbability preSnapHomeTeamWinProbability  \
# 5905        0.613358                      0.475384
#
#      preSnapVisitorTeamWinProbability homeTeamWinProbabilityAdded  \
# 5905                         0.524616                    0.471527
#
#      visitorTeamWinProbilityAdded expectedPoints expectedPointsAdded  \
# 5905                    -0.471527       2.319934            4.680066
#
#      foulName1 foulName2 foulNFLId1 foulNFLId2 line_of_scrimmage
# 5905       NaN       NaN        NaN        NaN                72

# %%
play_info.playDescription
# Out:
# '(:50) (Shotgun) K.Cousins pass deep right to K.Osborn for 28 yards, TOUCHDOWN [A.McNeill].'

# %%
ngs_df.loc[(ngs_df.gameId == game_id) & (ngs_df.playId == play_id) & (ngs_df.frameId == 1)].sort_values("nflId")
# Out:
#             gameId  playId    nflId         displayName  frameId  \
# 557437  2022092504    4168     -1.0            football        1
# 557129  2022092504    4168  38632.0        Kirk Cousins        1
# 557143  2022092504    4168  40488.0        Adam Thielen        1
# 557157  2022092504    4168  44834.0      Charles Harris        1
# 557171  2022092504    4168  44888.0       Alex Anzalone        1
# 557185  2022092504    4168  46099.0         Mike Hughes        1
# 557199  2022092504    4168  46131.0       Brian O'Neill        1
# 557213  2022092504    4168  46259.0      DeShon Elliott        1
# 557227  2022092504    4168  47801.0    Garrett Bradbury        1
# 557241  2022092504    4168  47833.0           Irv Smith        1
# 557255  2022092504    4168  47864.0         Will Harris        1
# 557269  2022092504    4168  47885.0  Alexander Mattison        1
# 557283  2022092504    4168  47929.0     Amani Oruwariye        1
# 557297  2022092504    4168  52411.0         Jeff Okudah        1
# 557311  2022092504    4168  52430.0    Justin Jefferson        1
# 557325  2022092504    4168  52466.0      Ezra Cleveland        1
# 557339  2022092504    4168  52475.0       Julian Okwara        1
# 557353  2022092504    4168  52584.0         K.J. Osborn        1
# 557367  2022092504    4168  52980.0         Juju Hughes        1
# 557381  2022092504    4168  53452.0  Christian Darrisaw        1
# 557395  2022092504    4168  53501.0        Alim McNeill        1
# 557409  2022092504    4168  54467.0    Aidan Hutchinson        1
# 557423  2022092504    4168  54524.0           Ed Ingram        1
#
#                               time  jerseyNumber      club playDirection  \
# 557437  2022-09-25 16:09:45.599999           NaN  football         right
# 557129  2022-09-25 16:09:45.599999           8.0       MIN         right
# 557143  2022-09-25 16:09:45.599999          19.0       MIN         right
# 557157  2022-09-25 16:09:45.599999          53.0       DET         right
# 557171  2022-09-25 16:09:45.599999          34.0       DET         right
# 557185  2022-09-25 16:09:45.599999          23.0       DET         right
# 557199  2022-09-25 16:09:45.599999          75.0       MIN         right
# 557213  2022-09-25 16:09:45.599999           5.0       DET         right
# 557227  2022-09-25 16:09:45.599999          56.0       MIN         right
# 557241  2022-09-25 16:09:45.599999          84.0       MIN         right
# 557255  2022-09-25 16:09:45.599999          25.0       DET         right
# 557269  2022-09-25 16:09:45.599999           2.0       MIN         right
# 557283  2022-09-25 16:09:45.599999          24.0       DET         right
# 557297  2022-09-25 16:09:45.599999           1.0       DET         right
# 557311  2022-09-25 16:09:45.599999          18.0       MIN         right
# 557325  2022-09-25 16:09:45.599999          72.0       MIN         right
# 557339  2022-09-25 16:09:45.599999          99.0       DET         right
# 557353  2022-09-25 16:09:45.599999          17.0       MIN         right
# 557367  2022-09-25 16:09:45.599999          33.0       DET         right
# 557381  2022-09-25 16:09:45.599999          71.0       MIN         right
# 557395  2022-09-25 16:09:45.599999          54.0       DET         right
# 557409  2022-09-25 16:09:45.599999          97.0       DET         right
# 557423  2022-09-25 16:09:45.599999          67.0       MIN         right
#
#                  x      y          s     a   dis       o     dir event
# 557437  100.419998  13.66  20.889999  4.49  2.11     NaN     NaN   NaN
# 557129   72.890000  32.49   2.100000  4.59  0.23  144.85  332.43   NaN
# 557143   94.570000  14.15   4.260000  1.04  0.42  185.55  190.86   NaN
# 557157   71.530000  29.83   1.620000  0.19  0.16   97.95   69.68   NaN
# 557171   83.510000  39.12   6.090000  2.52  0.61   18.61   27.03   NaN
# 557185  103.830000  17.20   8.650000  2.32  0.87  162.14  137.31   NaN
# 557199   73.930000  26.40   1.810000  0.61  0.19  156.70  126.01   NaN
# 557213  108.400000  25.82   6.910000  2.02  0.69  179.02  174.84   NaN
# 557227   79.080000  25.96   2.690000  1.30  0.28  134.46  156.41   NaN
# 557241   81.580000   8.57   4.200000  2.57  0.43  145.16  158.11   NaN
# 557255   87.970000   9.40   5.920000  3.64  0.59  123.53  141.14   NaN
# 557269   82.850000  40.57   5.860000  2.49  0.59  332.01   15.52   NaN
# 557283   98.700000  13.74   4.370000  3.02  0.45  113.69  142.70   NaN
# 557297   99.320000  46.07   6.900000  3.91  0.69  358.45    8.06   NaN
# 557311   99.560000  48.87   5.010000  3.34  0.52   33.32   12.89   NaN
# 557325   78.790000  34.03   1.800000  1.80  0.18   75.70   58.24   NaN
# 557339   73.350000  24.73   2.550000  0.50  0.26  125.52  145.81   NaN
# 557353  106.100000  12.34   8.720000  2.36  0.88  219.41  144.50   NaN
# 557367   98.100000  20.99   4.090000  0.67  0.41  183.89  175.43   NaN
# 557381   70.580000  32.96   0.630000  0.27  0.07  111.04  154.00   NaN
# 557395   74.020000  29.86   0.950000  1.08  0.10   69.69   46.10   NaN
# 557409   80.990000  24.45   3.300000  2.21  0.34  129.92  154.13   NaN
# 557423   73.510000  28.49   0.460000  2.49  0.05   47.91  354.30   NaN

# %%
ngs_df.loc[(ngs_df.gameId == game_id) & (ngs_df.playId == play_id) & (ngs_df.displayName == 'K.J. Osborn')]
# Out:
#             gameId  playId    nflId  displayName  frameId  \
# 557353  2022092504    4168  52584.0  K.J. Osborn        1
# 557354  2022092504    4168  52584.0  K.J. Osborn        2
# 557355  2022092504    4168  52584.0  K.J. Osborn        3
# 557356  2022092504    4168  52584.0  K.J. Osborn        4
# 557357  2022092504    4168  52584.0  K.J. Osborn        5
# 557358  2022092504    4168  52584.0  K.J. Osborn        6
# 557359  2022092504    4168  52584.0  K.J. Osborn        7
# 557360  2022092504    4168  52584.0  K.J. Osborn        8
# 557361  2022092504    4168  52584.0  K.J. Osborn        9
# 557362  2022092504    4168  52584.0  K.J. Osborn       10
# 557363  2022092504    4168  52584.0  K.J. Osborn       11
# 557364  2022092504    4168  52584.0  K.J. Osborn       12
# 557365  2022092504    4168  52584.0  K.J. Osborn       13
# 557366  2022092504    4168  52584.0  K.J. Osborn       14
#
#                               time  jerseyNumber club playDirection       x  \
# 557353  2022-09-25 16:09:45.599999          17.0  MIN         right  106.10
# 557354  2022-09-25 16:09:45.700000          17.0  MIN         right  106.60
# 557355  2022-09-25 16:09:45.799999          17.0  MIN         right  107.09
# 557356  2022-09-25 16:09:45.900000          17.0  MIN         right  107.58
# 557357  2022-09-25 16:09:46.000000          17.0  MIN         right  108.07
# 557358  2022-09-25 16:09:46.099999          17.0  MIN         right  108.56
# 557359  2022-09-25 16:09:46.200000          17.0  MIN         right  109.06
# 557360  2022-09-25 16:09:46.299999          17.0  MIN         right  109.57
# 557361  2022-09-25 16:09:46.400000          17.0  MIN         right  110.08
# 557362  2022-09-25 16:09:46.500000          17.0  MIN         right  110.60
# 557363  2022-09-25 16:09:46.599999          17.0  MIN         right  111.15
# 557364  2022-09-25 16:09:46.700000          17.0  MIN         right  111.70
# 557365  2022-09-25 16:09:46.799999          17.0  MIN         right  112.26
# 557366  2022-09-25 16:09:46.900000          17.0  MIN         right  112.81
#
#             y     s     a   dis       o     dir                   event
# 557353  12.34  8.72  2.36  0.88  219.41  144.50                     NaN
# 557354  11.62  8.68  2.16  0.87  221.81  145.92                     NaN
# 557355  10.90  8.66  1.82  0.87  221.81  146.61                     NaN
# 557356  10.17  8.68  1.35  0.88  212.61  146.59                     NaN
# 557357   9.45  8.64  1.23  0.87  206.89  146.23            pass_arrived
# 557358   8.73  8.58  1.34  0.87  198.16  145.63     pass_outcome_caught
# 557359   8.04  8.52  1.68  0.86  189.19  144.33                     NaN
# 557360   7.35  8.42  2.18  0.85  170.87  142.66                     NaN
# 557361   6.70  8.29  2.52  0.83  156.64  141.18                     NaN
# 557362   6.07  8.16  2.66  0.82  148.23  139.43  pass_outcome_touchdown
# 557363   5.47  8.00  3.02  0.81  140.05  136.84                     NaN
# 557364   4.90  7.84  3.12  0.79  136.69  134.66                     NaN
# 557365   4.36  7.65  3.02  0.78  133.88  133.11                     NaN
# 557366   3.85  7.42  2.94  0.75  131.70  131.89                     NaN

# %%
ngs_df.loc[(ngs_df.gameId == 2022091100) & (ngs_df.playId == 2374)].loc[ngs_df.loc[(ngs_df.gameId == 2022091100) & (ngs_df.playId == 2374)].frameId < 9]
# Out:
#             gameId  playId    nflId    displayName  frameId  \
# 136689  2022091100    2374  38607.0  Demario Davis        1
# 136690  2022091100    2374  38607.0  Demario Davis        2
# 136691  2022091100    2374  38607.0  Demario Davis        3
# 136692  2022091100    2374  38607.0  Demario Davis        4
# 136693  2022091100    2374  38607.0  Demario Davis        5
# ...            ...     ...      ...            ...      ...
# 136978  2022091100    2374     -1.0       football        4
# 136979  2022091100    2374     -1.0       football        5
# 136980  2022091100    2374     -1.0       football        6
# 136981  2022091100    2374     -1.0       football        7
# 136982  2022091100    2374     -1.0       football        8
#
#                               time  jerseyNumber      club playDirection  \
# 136689  2022-09-11 14:55:37.500000          56.0        NO         right
# 136690  2022-09-11 14:55:37.599999          56.0        NO         right
# 136691  2022-09-11 14:55:37.700000          56.0        NO         right
# 136692  2022-09-11 14:55:37.799999          56.0        NO         right
# 136693  2022-09-11 14:55:37.900000          56.0        NO         right
# ...                            ...           ...       ...           ...
# 136978  2022-09-11 14:55:37.799999           NaN  football         right
# 136979  2022-09-11 14:55:37.900000           NaN  football         right
# 136980  2022-09-11 14:55:38.000000           NaN  football         right
# 136981  2022-09-11 14:55:38.099999           NaN  football         right
# 136982  2022-09-11 14:55:38.200000           NaN  football         right
#
#                 x      y     s     a   dis       o     dir  \
# 136689  65.660000  13.66  5.22  1.60  0.52  156.74  159.21
# 136690  65.860000  13.17  5.31  1.36  0.53  152.47  157.68
# 136691  66.060000  12.68  5.36  1.10  0.54  149.49  156.57
# 136692  66.280000  12.18  5.37  0.93  0.54  145.87  155.64
# 136693  66.510000  11.70  5.31  1.10  0.53  142.89  154.35
# ...           ...    ...   ...   ...   ...     ...     ...
# 136978  69.699997   2.39  4.68  1.93  0.49     NaN     NaN
# 136979  69.540001   1.95  4.77  2.03  0.48     NaN     NaN
# 136980  69.360001   1.50  4.79  1.35  0.48     NaN     NaN
# 136981  69.180000   1.06  4.76  0.60  0.48     NaN     NaN
# 136982  69.010002   0.62  4.74  0.56  0.47     NaN     NaN
#
#                       event
# 136689                  NaN
# 136690         pass_arrived
# 136691                  NaN
# 136692                  NaN
# 136693                  NaN
# ...                     ...
# 136978                  NaN
# 136979                  NaN
# 136980  pass_outcome_caught
# 136981                  NaN
# 136982                  NaN
#
# [184 rows x 17 columns]

# %%
''' 
Out of bounds plays don't need to have a tackle event: 2022110700_3429

'''
def filter_play_edges(ngs_play):
    events = set(ngs_play.events.unique())   # set of all events in 
    tocheck = ['fumble', 'penalty_flag', 'safety', 'pass_outcome_touchdown'] # items to check
    events_in_play = [i for i in tocheck if i in events]
    if len(events_in_play) != 0:
        return None
    
    # filter edges
    tocheck = ['out_of_bounds', 'touchdown'] # items to check
    end_events_in_play = [i for i in tocheck if i in events]
    if len(end_events_in_play) != 0:
        end_frame_id = ngs_df.query("event in @end_events_in_play").frameId.values[0]
        ngs_play = ngs_play.loc[ngs_play.frameId <= end_frame_id]
    
    return ngs_play

# %%
all_games = ngs_df.gameId.unique()

# %%
game_ex = all_games[0]
play_ex = 56

# %%
full_play = ngs_df.loc[(ngs_df.gameId == game_ex) & (ngs_df.playId == play_ex)].copy()

# %%
full_play.iloc[0:20,:]
# Out:
#         gameId  playId    nflId     displayName  frameId  \
# 0   2022090800      56  35472.0  Rodger Saffold        1
# 1   2022090800      56  35472.0  Rodger Saffold        2
# 2   2022090800      56  35472.0  Rodger Saffold        3
# 3   2022090800      56  35472.0  Rodger Saffold        4
# 4   2022090800      56  35472.0  Rodger Saffold        5
# 5   2022090800      56  35472.0  Rodger Saffold        6
# 6   2022090800      56  35472.0  Rodger Saffold        7
# 7   2022090800      56  35472.0  Rodger Saffold        8
# 8   2022090800      56  35472.0  Rodger Saffold        9
# 9   2022090800      56  35472.0  Rodger Saffold       10
# 10  2022090800      56  35472.0  Rodger Saffold       11
# 11  2022090800      56  35472.0  Rodger Saffold       12
# 12  2022090800      56  35472.0  Rodger Saffold       13
# 13  2022090800      56  35472.0  Rodger Saffold       14
# 14  2022090800      56  35472.0  Rodger Saffold       15
# 15  2022090800      56  35472.0  Rodger Saffold       16
# 16  2022090800      56  35472.0  Rodger Saffold       17
# 17  2022090800      56  35472.0  Rodger Saffold       18
# 18  2022090800      56  35472.0  Rodger Saffold       19
# 19  2022090800      56  35472.0  Rodger Saffold       20
#
#                           time  jerseyNumber club playDirection      x      y  \
# 0   2022-09-08 20:24:05.200000          76.0  BUF          left  88.37  27.27
# 1   2022-09-08 20:24:05.299999          76.0  BUF          left  88.47  27.13
# 2   2022-09-08 20:24:05.400000          76.0  BUF          left  88.56  27.01
# 3   2022-09-08 20:24:05.500000          76.0  BUF          left  88.64  26.90
# 4   2022-09-08 20:24:05.599999          76.0  BUF          left  88.72  26.80
# 5   2022-09-08 20:24:05.700000          76.0  BUF          left  88.80  26.70
# 6   2022-09-08 20:24:05.799999          76.0  BUF          left  88.87  26.64
# 7   2022-09-08 20:24:05.900000          76.0  BUF          left  88.91  26.59
# 8   2022-09-08 20:24:06.000000          76.0  BUF          left  88.94  26.57
# 9   2022-09-08 20:24:06.099999          76.0  BUF          left  88.95  26.58
# 10  2022-09-08 20:24:06.200000          76.0  BUF          left  88.92  26.60
# 11  2022-09-08 20:24:06.299999          76.0  BUF          left  88.90  26.63
# 12  2022-09-08 20:24:06.400000          76.0  BUF          left  88.84  26.68
# 13  2022-09-08 20:24:06.500000          76.0  BUF          left  88.75  26.74
# 14  2022-09-08 20:24:06.599999          76.0  BUF          left  88.65  26.82
# 15  2022-09-08 20:24:06.700000          76.0  BUF          left  88.53  26.91
# 16  2022-09-08 20:24:06.799999          76.0  BUF          left  88.39  27.00
# 17  2022-09-08 20:24:06.900000          76.0  BUF          left  88.23  27.09
# 18  2022-09-08 20:24:07.000000          76.0  BUF          left  88.09  27.19
# 19  2022-09-08 20:24:07.099999          76.0  BUF          left  87.93  27.28
#
#        s     a   dis       o     dir                event
# 0   1.62  1.15  0.16  231.74  147.90                  NaN
# 1   1.67  0.61  0.17  230.98  148.53         pass_arrived
# 2   1.57  0.49  0.15  230.98  147.05                  NaN
# 3   1.44  0.89  0.14  232.38  145.42                  NaN
# 4   1.29  1.24  0.13  233.36  141.95                  NaN
# 5   1.15  1.42  0.12  234.48  139.41  pass_outcome_caught
# 6   0.93  1.69  0.09  235.77  134.32                  NaN
# 7   0.68  1.74  0.07  240.00  131.01                  NaN
# 8   0.42  1.74  0.04  243.56  122.29                  NaN
# 9   0.14  1.83  0.01  246.07   85.87                  NaN
# 10  0.26  1.90  0.03  252.65  326.63                  NaN
# 11  0.51  2.45  0.04  257.66  315.55                  NaN
# 12  0.81  2.03  0.08  262.09  311.72                  NaN
# 13  1.10  1.65  0.11  266.35  307.22                  NaN
# 14  1.30  1.22  0.13  270.10  306.54                  NaN
# 15  1.50  0.85  0.15  278.44  305.55                  NaN
# 16  1.62  0.49  0.17  283.60  304.10                  NaN
# 17  1.72  0.26  0.18  288.76  302.08               tackle
# 18  1.73  0.21  0.17  291.51  302.30                  NaN
# 19  1.78  0.29  0.19  301.72  301.05                  NaN

# %%
for game_index, game_id in enumerate(all_games):
    all_play_ids = plays.query("gameId == @game_id").playId.values
    for play_id in all_play_ids:
        try:
            current_id = f"{str(game_id)}_{str(play_id)}"
            
            play_info = get_play(plays, game_id, play_id)                   # store play info in series
            if not np.isnan(play_info.penaltyYards):
                continue
            tackler_id = get_tackler_id(tackles, game_id, play_id)          # store tackler id
            if tackler_id == None:
                continue

            ngs_full_play = ngs_df.loc[(ngs_df.gameId == game_id) & (ngs_df.playId == play_id)].copy()
        
        except Exception as e:
            print(f"Skipping play bc {e}")
